# %% [markdown]
# <a href="https://colab.research.google.com/github/arunkashish/Arunkumar.S/blob/main/Copy_of_Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
ss=pd.read_csv('/content/college_1.csv')
dd=pd.read_csv("/content/college_2.csv")
df = pd.concat(
    map(pd.read_csv, ['/content/college_1.csv', "/content/college_2.csv"]), ignore_index=True)
print(df)
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
df1=df[(df["CodeKata Score"]>15000)]
df1.to_csv('Exceeed expectations.csv')
print("\nExceeded expectations.csv is created\n")
df1

df2=df[(df["CodeKata Score"]<15000)&(df1["CodeKata Score"]>10000)]
df2.to_csv('Reaced_expectations.csv')
print("\nReached_expectations.csv is created\n")
df2

df3=df[(df["CodeKata Score"]>7000)&(df1["CodeKata Score"]<10000)]
df3.to_csv('Nees_Improvement.csv')
print("\nNeeds_Improvement.csv is created\n")
df3

df4=df[(df["CodeKata Score"]<7000)]
df4.to_csv('Unatisfactory.csv')
print("\nUnsatisfactory.csv is created\n")
df4

print("\nThe total no. of rows in merged CSVs (college_1.csv and college_2.csv): {}".format(df3.shape[0]))

x=[df1,df2,df3,df4]
# Out:
# Exceeded expectations.csv is created
#
#
# Reached_expectations.csv is created
#
#
# Needs_Improvement.csv is created
#
#
# Unsatisfactory.csv is created
#
#
# The total no. of rows in merged CSVs (college_1.csv and college_2.csv): 0

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df["Previous Geekions"].mean()
# Out:
# 3842.3529411764707

# %%
df["CodeKata Score"].mean()
# Out:
# 4051.764705882353

# %% [markdown]
# ###### No of students participated

# %%
df["Name"] = df["Name"].str.lower() 
df["Name"] = df["Name"].str.strip()
df["Name"].isnull().sum()

print(df["Name"].nunique())
# Out:
# 118

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
x=['python','mysql','python_en','computational_thinking']

for i in x:
  print((i,df[i].mean()))
# Out:
# ('python', 54.35294117647059)
# ('mysql', 23.5)
# ('python_en', 29.65714285714286)
# ('computational_thinking', 2.2)

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.Rising.nlargest(3)
# Out:
# 92     3140
# 86     2000
# 102    2000
# Name: Rising, dtype: int64

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df["Previous Geekions"].nlargest(3)
# Out:
# 0    24500
# 1    21740
# 2    19680
# Name: Previous Geekions, dtype: int64

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
import matplotlib.pyplot as plt
import plotly.express as px
piee=px.pie(names=df["Department"],values=df["CodeKata Score"])
piee
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
plt.bar(df["Department"],df["CodeKata Score"])
px.histogram(x=df["CodeKata Score"],y=df["CodeKata Score"],color=df["Name"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(df,x="Department",y='CodeKata Score',size='CodeKata Score',color='Name',title="Department wise Topper")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
